# %% [markdown]
# <h2 style = "color : blue"> Case Study - Online Retailer</h2>
# <h4 sytle = "color : blue"> Example -1</h4>
#
# ##### Bar Chart - Plot sales across each product category
#
# - A bar chart uses bars to show comparisons between categories of data.
# - A bar graph will always have two axis.
# - One axis will generally have numerical values or measures,
# - The other will describe the types of categories being compared or dimensions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
product_category= np.array(['Furniture', 'Technology', 'Office Supplies'])
sales = [4110451.90, 4744557.50, 3787492.52]

# %%
plt.bar(product_category, sales)
plt.show()

# %%
# plotting bar chat and setting bar width to 0.5 and aligning it to center.

plt.bar(product_category, sales, width = 0.5, align='center', edgecolor = 'Black', color = 'Blue')

# Adding and formatting title

plt.title("Sales Across Product Category", fontdict = {"fontsize":20, "fontweight":5, "color":"Green"})

# lebeling Axes
plt.xlabel("Product Category", fontdict = {"fontsize":12, "fontweight":5, "color":"Black"})
plt.ylabel("Sales", fontdict = {"fontsize":12, "fontweight":5, "color":"Black"})

# Modifying the ticks to show information in (million dollaras)

ticks = np.arange(0, 6000000, 1000000)
labels = ["{}M" .format(i//1000000) for i in ticks]
plt.yticks(ticks, labels)
# Out:
# ([<matplotlib.axis.YTick at 0x12de01c79d0>,
# ...
#  [Text(0, 0, '0M'),
#   Text(0, 1000000, '1M'),
#   Text(0, 2000000, '2M'),
#   Text(0, 3000000, '3M'),
#   Text(0, 4000000, '4M'),
#   Text(0, 5000000, '5M')])

# %% [markdown]
# <h2 style = "color:Blue">Scatter plot</h2>

# %%
name = (['Sharon', 'Manoj', 'Purnima', 'Venkatar', 'Ananth', 'Rajesh', 'Meenakshi', 'Jyoti'])
gender = (['Female', 'Male', 'Fmale', 'Male', 'Female', 'Male', 'Female', 'Female'])
grade = (['3X', '2X', '5X', '7X', '3X', '3X', '6X', '3X'])
work_Location = (['Mumbai HO', 'Mumbai HURC', 'Unilever R&D Bangalore', 'Unilever R&D Bangalore', 'Mumbai HURC', 'Lucknow Regional Office', 'Mumbai Regional Office', 'Lucknow Regional Office'])


plt.scatter(name, grade, linewidths = 0.5, alpha = 0.7, s= 50 )
plt.title("Name waise Grade Category", fontdict = {"fontsize":20, "fontweight":5, "color":"Green"})


plt.xlabel("name", fontdict = {"fontsize":10, "fontweight":5, "color":"Black"})
plt.ylabel("grade", fontdict = {"fontsize":10, "fontweight":5, "color":"Black"})

plt.xticks(rotation = 75)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Sharon'),
#   Text(1, 0, 'Manoj'),
#   Text(2, 0, 'Purnima'),
#   Text(3, 0, 'Venkatar'),
#   Text(4, 0, 'Ananth'),
#   Text(5, 0, 'Rajesh'),
#   Text(6, 0, 'Meenakshi'),
#   Text(7, 0, 'Jyoti')])

# %%
list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]

plt.hist(list_1, bins= 10, edgecolor = 'Blue')
plt.show()

# %%
list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]
# plt.hist(list_1, edgecolor = 'white')
# plt.hist(list_1, bins = 4, edgecolor = 'white')
plt.hist(list_1, bins = 4, range =[40, 80], edgecolor = 'white')
# plt.hist( list_1, range =[40, 80])
plt.show()

# %%
#Find the interquartile range for the box plot created over the following list:
list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]
#[Hint: use np.percentile to find the percentile values]
percentile = np.percentile(list_1, [25,75])
plt.boxplot(list_1)
print("Percentile 1-75 of list_1:{}", percentile)
# Out:
# Percentile 1-75 of list_1:{} [48.5475 66.3025]

# %%
fx, ax = plt.subplots(ncols = 3, nrows = 2, sharex = True, sharey=True)
